# %%
import os, sys
from pathlib import Path
import xarray as xr
import rootpath

ROOT_PATH = Path(rootpath.detect())
os.chdir(str(ROOT_PATH))
sys.path.append(str(ROOT_PATH))

from _shared import getConfig
config = getConfig()

DATA_FOLDER = ROOT_PATH/config['d']['era5']
CLIMATE_FOLDER = DATA_FOLDER/"climate"
POPULATION_FOLDER = DATA_FOLDER/"population"

# %%
# import pandas as pd
# pop = xr.open_dataarray(POPULATION_FOLDER/'pop_era5_rel.nc')
# # POP TO CSV
# t = pd.melt(pop.to_pandas(), ignore_index = False)
# t.to_csv(DATA_FOLDER/'pop.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 pop = xr.open_dataarray(POPULATION_FOLDER/'pop_era5_rel.nc')
#       2 # POP TO CSV
# ----> 3 t = pd.melt(pop.to_pandas(), ignore_index = False)
#       4 t.to_csv(DATA_FOLDER/'pop.csv')
#
# NameError: name 'pd' is not defined

# %%
temperature = xr.open_mfdataset(str(CLIMATE_FOLDER/'*.nc'))
temperature = temperature.t2m  - 273.15
temperature
# Out:
# <xarray.DataArray 't2m' (valid_time: 743688, latitude: 21, longitude: 41)> Size: 3GB
# dask.array<sub, shape=(743688, 21, 41), dtype=float32, chunksize=(4392, 11, 21), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#   * valid_time  (valid_time) datetime64[ns] 6MB 1940-01-01 ... 2024-11-01T23:...
#   * latitude    (latitude) float64 168B 50.0 49.75 49.5 ... 45.5 45.25 45.0
#   * longitude   (longitude) float64 328B 8.0 8.25 8.5 8.75 ... 17.5 17.75 18.0
#     expver      (valid_time) <U4 12MB dask.array<chunksize=(8784,), meta=np.ndarray>

# %%
temperature = temperature.resample(valid_time="d").mean()
temperature
# Out:
# <xarray.DataArray 't2m' (valid_time: 30987, latitude: 21, longitude: 41)> Size: 107MB
# dask.array<stack, shape=(30987, 21, 41), dtype=float32, chunksize=(1, 11, 21), chunktype=numpy.ndarray>
# Coordinates:
#     number      int64 8B 0
#   * latitude    (latitude) float64 168B 50.0 49.75 49.5 ... 45.5 45.25 45.0
#   * longitude   (longitude) float64 328B 8.0 8.25 8.5 8.75 ... 17.5 17.75 18.0
#   * valid_time  (valid_time) datetime64[ns] 248kB 1940-01-01 ... 2024-11-01

# %%
temperature.to_dataframe().to_csv(DATA_FOLDER/'temp.csv')

# %%
d = temperature.to_dataframe()
d
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7ff59e124ef0>>
# Traceback (most recent call last):
#   File "/home/preschenhofer/.local/micromamba/envs/energy/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
#
# KeyboardInterrupt:
#                                number        t2m
# valid_time latitude longitude
# 1940-01-01 50.0     8.00            0  -3.845556
#                     8.25            0  -3.558284
#                     8.50            0  -3.678401
#                     8.75            0  -3.491226
#                     9.00            0  -4.359228
# ...                               ...        ...
# 2024-11-01 45.0     17.00           0  10.725780
#                     17.25           0  11.063263
#                     17.50           0  11.446889
#                     17.75           0  11.677440
#                     18.00           0  11.710399
#
# [26679807 rows x 2 columns]

# %%
# Out:
#                                number        t2m
# valid_time latitude longitude
# 1940-01-01 50.0     8.00            0  -3.845556
#                     8.25            0  -3.558284
#                     8.50            0  -3.678401
#                     8.75            0  -3.491226
#                     9.00            0  -4.359228
# ...                               ...        ...
# 2024-11-01 45.0     17.00           0  10.725780
#                     17.25           0  11.063263
#                     17.50           0  11.446889
#                     17.75           0  11.677440
#                     18.00           0  11.710399
#
# [26679807 rows x 2 columns]
